# %% [markdown]
# # Computational Thinking: Expressions and Simple Scripts
#
# ## Student Lab Notebook
#
# ### Goals
# By the end of this notebook, you should be able to:
#
# - run Python code in a notebook;
# - distinguish an expression from a value;
# - predict the result of simple expressions before executing them;
# - identify basic numeric types;
# - create and update variables;
# - build a small computational solution from inputs, operations, and outputs;
# - recognize syntax, name, and logic errors.
#
# ### Working habit for today
#
# **Predict → Run → Inspect → Explain**
#
# Do not treat Python as a guessing machine. Before you run a new expression, write down what you expect it to produce.

# %% [markdown]
# ## 0. Today's question
#
# > **How do we turn a simple problem into something a computer can execute?**
#
# Consider this problem:
#
# > A dataset contains **1,250 records**. Processing one record takes approximately **0.018 seconds**. Approximately how long will the entire dataset take to process?
#
# Before writing Python, answer:
#
# 1. What are the **inputs**?
# 2. What **operation** is needed?
# 3. What is the expected **output**?

# %% [markdown]
# ### Your response
#
# **Inputs:**
# -
#
# **Operation:**
# -
#
# **Output:**
# -

# %% [markdown]
# ## 1. First Python expressions
#
# An **expression** is Python code that evaluates to a value.
#
# Before running each cell below, predict the result.

# %% [markdown]
# ### Prediction 1
# What will `2 + 3` produce?
#
# **Prediction:**

# %%
2 + 3

# %% [markdown]
# ### Prediction 2
# What will `10 * 4` produce?
#
# **Prediction:**

# %%
10 * 4

# %% [markdown]
# ### Reflection
#
# In one sentence, describe what Python did when you ran those expressions.
#
# **Your answer:**

# %% [markdown]
# ## 2. Predict → Run → Explain
#
# For each expression:
#
# 1. write your prediction;
# 2. run the expression;
# 3. compare the result with your prediction;
# 4. explain any surprise.

# %% [markdown]
# ### Expression 1: `3 + 4`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
3 + 4

# %% [markdown]
# ### Expression 2: `3 * 4`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
3 * 4

# %% [markdown]
# ### Expression 3: `3 + 4 * 2`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
3 + 4 * 2

# %% [markdown]
# ### Expression 4: `(3 + 4) * 2`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
(3 + 4) * 2

# %% [markdown]
# ### Expression 5: `10 / 4`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
10 / 4

# %% [markdown]
# ### Expression 6: `10 // 4`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
10 // 4

# %% [markdown]
# ### Expression 7: `10 % 4`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
10 % 4

# %% [markdown]
# ### Expression 8: `2 ** 5`
#
# **Prediction:**
#
# **Explanation after running:**

# %%
2 ** 5

# %% [markdown]
# ### Compare the operators
#
# Complete the table in words.
#
# | Operator | Your description |
# |---|---|
# | `+` | |
# | `*` | |
# | `/` | |
# | `//` | |
# | `%` | |
# | `**` | |

# %% [markdown]
# ## 3. Numerical types
#
# Python values have **types**. We will focus on two numerical types:
#
# - `int` — integers
# - `float` — floating-point numbers
#
# Predict the output before running each cell.

# %% [markdown]
# ### Type check 1
# Predict the result of `type(3)`.
#
# **Prediction:**

# %%
type(3)

# %% [markdown]
# ### Type check 2
# Predict the result of `type(3.0)`.
#
# **Prediction:**

# %%
type(3.0)

# %% [markdown]
# ### Type check 3
# Predict the result of `type(10 / 2)`.
#
# **Prediction:**

# %%
type(10 / 2)

# %% [markdown]
# ### Mixed numerical types
#
# Predict both the **value** and the **type** of the following expression.

# %% [markdown]
# **Predicted value:**
#
# **Predicted type:**

# %%
2 + 3.0

# %%
type(2 + 3.0)

# %% [markdown]
# ### Quick checkpoint
#
# Without running the code first, choose one:
#
# ```python
# type(7 / 2)
# ```
#
# - A. `int`
# - B. `float`
# - C. error
# - D. impossible to determine
#
# **Your choice:**
# **Why?**

# %%
type(7 / 2)

# %% [markdown]
# ## 4. Variables and assignment
#
# A variable is a **name associated with a value**.
#
# Run:

# %%
records = 1250
seconds_per_record = 0.018

# %% [markdown]
# Now compute a new value using those variables.
#
# Before running the next cell, predict the value of `total_seconds`.

# %% [markdown]
# **Prediction:**

# %%
total_seconds = records * seconds_per_record
total_seconds

# %% [markdown]
# ### Explain the assignment
#
# In your own words, explain what this statement does:
#
# ```python
# records = 1250
# ```
#
# **Your answer:**

# %% [markdown]
# ### Reassignment
#
# Predict what `records` will contain after this cell is executed.

# %%
records = 1250
records = 2500
records

# %% [markdown]
# **Explain why:**

# %% [markdown]
# ## 5. Notebook state
#
# Notebook cells can be executed in an order that differs from the order in which they appear.
#
# ### Experiment
#
# 1. Run the next cell.
# 2. Run the cell after it.
# 3. Change `x = 10` to `x = 100`, but **do not run the first cell again**.
# 4. Run only the second cell.
# 5. Explain the result.

# %%
x = 10

# %%
x * 2

# %% [markdown]
# ### Explain notebook state
#
# Why can the visible code in a notebook differ from the state currently stored in Python?
#
# **Your answer:**

# %% [markdown]
# ## 6. Guided Lab: Processing-Time Estimator
#
# ### Problem
#
# A data-processing job has:
#
# - a known number of records;
# - an estimated processing time per record.
#
# Write a short Python program that estimates the total processing time.
#
# ### Step 1 — Describe the computation before coding
#
# **Inputs:**
# -
# -
#
# **Operation:**
# -
#
# **Output:**
# -

# %% [markdown]
# ### Step 2 — Represent the inputs

# %%
records = 1250
seconds_per_record = 0.018

# %% [markdown]
# ### Step 3 — Compute the total time

# %%
# Create a variable named total_seconds.
# Use the two input variables above.

# %% [markdown]
# ### Step 4 — Display the result

# %%
# Print total_seconds.

# %% [markdown]
# ### Step 5 — Convert seconds to minutes
#
# Create a new variable named `total_minutes`.

# %%
# Compute total_minutes and print it.

# %% [markdown]
# ### Step 6 — Test another case
#
# Change `records` to `1_000_000`, then rerun the relevant cells.
#
# Record the new results.
#
# **Total seconds:**
# **Total minutes:**

# %% [markdown]
# ### Reflection
#
# Which parts of your program represent the **specific problem instance**, and which part represents the **general computation**?
#
# **Specific data/parameters:**
#
# **General computation:**

# %% [markdown]
# ## 7. Lab Challenge A — Predict Before Executing
#
# Do not run the code yet.
#
# ```python
# records = 100
# seconds_per_record = 0.25
#
# total_seconds = records * seconds_per_record
# total_minutes = total_seconds / 60
# ```
#
# Predict:
#
# **`total_seconds` =**
#
# **`total_minutes` =**

# %%
records = 100
seconds_per_record = 0.25

total_seconds = records * seconds_per_record
total_minutes = total_seconds / 60

print(total_seconds)
print(total_minutes)

# %% [markdown]
# ### Compare prediction and result
#
# Did your prediction match Python? If not, explain the difference.
#
# **Your answer:**

# %% [markdown]
# ## 8. Lab Challenge B — Modify the Model
#
# Suppose the work can be divided among four identical processors.
#
# Add:
#
# ```python
# processors = 4
# ```
#
# Then estimate ideal parallel execution time with:
#
# ```python
# parallel_seconds = total_seconds / processors
# ```
#
# Complete the code below.

# %%
processors = 4

# Compute parallel_seconds.

# Print parallel_seconds.

# %% [markdown]
# ### Model assumption
#
# What assumption is the expression
#
# ```python
# total_seconds / processors
# ```
#
# making about parallel processing?
#
# **Your answer:**

# %% [markdown]
# ## 9. Lab Challenge C — Write a Small Program
#
# Choose **one** problem:
#
# 1. Fahrenheit → Celsius
# 2. miles → kilometers
# 3. number of files × average file size → total storage
# 4. records / elapsed seconds → records per second
#
# Your program must contain:
#
# - at least two variables;
# - at least two expressions;
# - at least one newly computed variable;
# - at least one `print()` statement;
# - meaningful variable names.
#
# ### Before coding
#
# **Problem chosen:**
#
# **Inputs:**
#
# **Operations:**
#
# **Output:**

# %%
# Write your program here.

# %% [markdown]
# ### Test your program
#
# Change at least one input value and run the program again.
#
# **What did you change?**
#
# **What result did you expect?**
#
# **What result did Python produce?**

# %% [markdown]
# ## 10. Debugging Micro-Exercise
#
# For each example:
#
# 1. identify the problem;
# 2. classify it as a **syntax error**, **name/case error**, or **logic error**;
# 3. write a corrected version.
#
# ### Example A
#
# ```python
# records = 1000
# seconds = 20
# rate = records / Seconds
# print(rate)
# ```
#
# **Classification:**
#
# **Explanation:**

# %%
# Corrected version of Example A

# %% [markdown]
# ### Example B
#
# ```python
# records = 1000
# seconds = 20
# rate = records seconds
# print(rate)
# ```
#
# **Classification:**
#
# **Explanation:**

# %%
# Corrected version of Example B

# %% [markdown]
# ### Example C
#
# ```python
# records = 1000
# seconds = 20
# rate = seconds / records
# print(rate)
# ```
#
# Suppose the intended result is **records per second**.
#
# **Classification:**
#
# **Explanation:**

# %%
# Corrected version of Example C

# %% [markdown]
# ## 11. Exit Ticket
#
# ### 1. Predict
#
# Without running first:
#
# ```python
# x = 8
# y = 3
# z = x / y
# ```
#
# What is the **value** of `z`?
#
# What is the **type** of `z`?

# %%
# Run this only after recording your prediction.
x = 8
y = 3
z = x / y

print(z)
print(type(z))

# %% [markdown]
# ### 2. Explain
#
# In one sentence, explain the difference between:
#
# ```python
# 3 + 4
# ```
#
# and:
#
# ```python
# result = 3 + 4
# ```
#
# **Your answer:**

# %% [markdown]
# ### 3. Computational thinking
#
# For your Lab Challenge C program, identify:
#
# **Input(s):**
#
# **Operation(s):**
#
# **Output:**
#
# **One assumption:**

# %% [markdown]
# ## 12. Optional Extension
#
# A sensor generates **240 observations per minute**. Each observation requires **16 bytes**.
#
# Estimate the storage required for **one hour** of observations.
#
# ### Before coding
#
# **Inputs:**
#
# **Operations:**
#
# **Output:**

# %%
# Write your solution here.

# %% [markdown]
# ### Extension reflection
#
# Change one input and predict how the output will change before rerunning the program.
#
# **Input changed:**
#
# **Prediction:**
#
# **Observed result:**

# %% [markdown]
# ---
# ## Reference
#
# This lab is based primarily on the opening material in:
#
# John V. Guttag, *Introduction to Computation and Programming Using Python*, 3rd ed., MIT Press.
#
# Book page:
# https://mitpress.mit.edu/9780262542364/introduction-to-computation-and-programming-using-python/
